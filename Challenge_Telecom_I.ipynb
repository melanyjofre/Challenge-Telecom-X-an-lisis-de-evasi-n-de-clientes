# %% [markdown]
# <a href="https://colab.research.google.com/github/melanyjofre/Challenge-Telecom-X-an-lisis-de-evasi-n-de-clientes/blob/main/Challenge_Telecom_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **📌 Extracción**

# %%
import pandas as pd

# %%
with open('/content/TelecomX_diccionario.md', 'r', encoding='utf-8') as file:
    diccionario_content = file.read()
print(diccionario_content)
# Out:
# #### Diccionario de datos
#
# - `customerID`: número de identificación único de cada cliente
# - `Churn`: si el cliente dejó o no la empresa
# - `gender`: género (masculino y femenino)
# - `SeniorCitizen`: información sobre si un cliente tiene o no una edad igual o mayor a 65 años
# - `Partner`: si el cliente tiene o no una pareja
# - `Dependents`: si el cliente tiene o no dependientes
# - `tenure`: meses de contrato del cliente
# - `PhoneService`: suscripción al servicio telefónico
# - `MultipleLines`: suscripción a más de una línea telefónica
# - `InternetService`: suscripción a un proveedor de internet
# - `OnlineSecurity`: suscripción adicional de seguridad en línea
# - `OnlineBackup`: suscripción adicional de respaldo en línea
# - `DeviceProtection`: suscripción adicional de protección del dispositivo
# - `TechSupport`: suscripción adicional de soporte técnico, menor tiempo de espera
# - `StreamingTV`: suscripción de televisión por cable
# ...

# %%
df_local = pd.read_json('TelecomX_Data.json')
df_local.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %% [markdown]
# #**🔧 Transformación**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   object
#  5   customer.Dependents        7267 non-null   object
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   object
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
# ...

# %%
df.head()
# Out:
#    customerID Churn customer.gender  customer.SeniorCitizen customer.Partner  \
# 0  0002-ORFBO    No          Female                       0              Yes
# 1  0003-MKNFE    No            Male                       0               No
# 2  0004-TLHLJ   Yes            Male                       0               No
# 3  0011-IGKFF   Yes            Male                       1              Yes
# 4  0013-EXCHZ   Yes          Female                       1              Yes
#
#   customer.Dependents  customer.tenure phone.PhoneService phone.MultipleLines  \
# 0                 Yes                9                Yes                  No
# 1                  No                9                Yes                 Yes
# 2                  No                4                Yes                  No
# 3                  No               13                Yes                  No
# 4                  No                3                Yes                  No
#
# ...

# %%
df.dtypes
# Out:
# customerID                    object
# Churn                         object
# customer.gender               object
# customer.SeniorCitizen         int64
# customer.Partner              object
# customer.Dependents           object
# customer.tenure                int64
# phone.PhoneService            object
# phone.MultipleLines           object
# internet.InternetService      object
# internet.OnlineSecurity       object
# internet.OnlineBackup         object
# internet.DeviceProtection     object
# internet.TechSupport          object
# internet.StreamingTV          object
# internet.StreamingMovies      object
# account.Contract              object
# account.PaperlessBilling      object
# account.PaymentMethod         object
# account.Charges.Monthly      float64
# account.Charges.Total         object
# dtype: object

# %% [markdown]
# Diccionario de datos:
#
# `customerID`: número de identificación único de cada cliente
#
# `Churn`: si el cliente dejó o no la empresa
#
# `gender`: género (masculino y femenino)
#
# `SeniorCitizen`: información sobre si un cliente tiene o no una edad igual o mayor a 65 años
#
# `Partner`: si el cliente tiene o no una pareja
#
# `Dependents`: si el cliente tiene o no dependientes
#
# `Dependents`: meses de contrato del cliente
#
# `PhoneService`: suscripción al servicio telefónico
#
# `MultipleLines`: suscripción a más de una línea telefónica
#
# `InternetService`: suscripción a un proveedor de internet
#
# `OnlineSecurity`: suscripción adicional de seguridad en línea
#
# `OnlineBackup`: suscripción adicional de respaldo en línea
#
# `DeviceProtection`: suscripción adicional de protección del dispositivo
#
# `TechSupport`: suscripción adicional de soporte técnico, menor tiempo de espera
#
# `StreamingTV`: suscripción de televisión por cable
#
# `StreamingMovies`: suscripción de streaming de películas
#
# `Contract`: tipo de contrato
#
# `PaperlessBilling`: si el cliente prefiere recibir la factura en línea
#
# `PaymentMethod`: forma de pago
#
# `Charges.Monthly`: total de todos los servicios del cliente por mes
#
# `Charges.Total`: total gastado por el cliente

# %%
df.columns
# Out:
# Index(['customerID', 'Churn', 'customer.gender', 'customer.SeniorCitizen',
#        'customer.Partner', 'customer.Dependents', 'customer.tenure',
#        'phone.PhoneService', 'phone.MultipleLines', 'internet.InternetService',
#        'internet.OnlineSecurity', 'internet.OnlineBackup',
#        'internet.DeviceProtection', 'internet.TechSupport',
#        'internet.StreamingTV', 'internet.StreamingMovies', 'account.Contract',
#        'account.PaperlessBilling', 'account.PaymentMethod',
#        'account.Charges.Monthly', 'account.Charges.Total'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# customerID                   0
# Churn                        0
# customer.gender              0
# customer.SeniorCitizen       0
# customer.Partner             0
# customer.Dependents          0
# customer.tenure              0
# phone.PhoneService           0
# phone.MultipleLines          0
# internet.InternetService     0
# internet.OnlineSecurity      0
# internet.OnlineBackup        0
# internet.DeviceProtection    0
# internet.TechSupport         0
# internet.StreamingTV         0
# internet.StreamingMovies     0
# account.Contract             0
# account.PaperlessBilling     0
# account.PaymentMethod        0
# account.Charges.Monthly      0
# account.Charges.Total        0
# dtype: int64

# %%
#sumo los valores duplicados
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Converti la columna account.Charges.Total a tipo float y errors para manejar posibles errores durante la conversión.
#con fillna transforma los NaN en 0

df['account.Charges.Total'] = pd.to_numeric(df['account.Charges.Total'], errors='coerce')
df['account.Charges.Total'] = df['account.Charges.Total'].fillna(0)
df.dtypes
# Out:
# customerID                    object
# Churn                         object
# customer.gender               object
# customer.SeniorCitizen         int64
# customer.Partner              object
# customer.Dependents           object
# customer.tenure                int64
# phone.PhoneService            object
# phone.MultipleLines           object
# internet.InternetService      object
# internet.OnlineSecurity       object
# internet.OnlineBackup         object
# internet.DeviceProtection     object
# internet.TechSupport          object
# internet.StreamingTV          object
# internet.StreamingMovies      object
# account.Contract              object
# account.PaperlessBilling      object
# account.PaymentMethod         object
# account.Charges.Monthly      float64
# account.Charges.Total        float64
# dtype: object

# %%
df['customer.SeniorCitizen'].unique()
# Out:
# array([0, 1])

# %%
df['customer.Partner'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['customer.Dependents'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Churn'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df['account.PaperlessBilling'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['account.PaymentMethod'].unique()
# Out:
# array(['Mailed check', 'Electronic check', 'Credit card (automatic)',
#        'Bank transfer (automatic)'], dtype=object)

# %%
df['account.Contract'].unique()
# Out:
# array(['One year', 'Month-to-month', 'Two year'], dtype=object)

# %%
import numpy as np
df['Churn'] = df['Churn'].replace('', np.nan)
print(f"Unique values in 'Churn' after cleaning: {df['Churn'].unique()}")
# Out:
# Unique values in 'Churn' after cleaning: ['No' 'Yes' nan]

# %%
# Eliminar filas donde 'Churn' es NaN
df_cleaned = df.dropna(subset=['Churn'])

# Verificar el conteo de valores nulos después de la eliminación
df_cleaned.isnull().sum()

# Actualizar el DataFrame original con la versión limpia si es necesario, o trabajar con df_cleaned
df = df_cleaned.copy()

df.head()
# Out:
#    customerID Churn customer.gender  customer.SeniorCitizen customer.Partner  \
# 0  0002-ORFBO    No          Female                       0              Yes
# 1  0003-MKNFE    No            Male                       0               No
# 2  0004-TLHLJ   Yes            Male                       0               No
# 3  0011-IGKFF   Yes            Male                       1              Yes
# 4  0013-EXCHZ   Yes          Female                       1              Yes
#
#   customer.Dependents  customer.tenure phone.PhoneService phone.MultipleLines  \
# 0                 Yes                9                Yes                  No
# 1                  No                9                Yes                 Yes
# 2                  No                4                Yes                  No
# 3                  No               13                Yes                  No
# 4                  No                3                Yes                  No
#
# ...

# %% [markdown]
# #**📊 Carga y análisis**

# %%
df.describe()
# Out:
#        customer.SeniorCitizen  customer.tenure  account.Charges.Monthly  \
# count             7267.000000      7267.000000              7267.000000
# mean                 0.162653        32.346498                64.720098
# std                  0.369074        24.571773                30.129572
# min                  0.000000         0.000000                18.250000
# 25%                  0.000000         9.000000                35.425000
# 50%                  0.000000        29.000000                70.300000
# 75%                  0.000000        55.000000                89.875000
# max                  1.000000        72.000000               118.750000
#
#        account.Charges.Total
# count            7267.000000
# mean             2277.182035
# std              2268.648587
# min                 0.000000
# 25%               396.200000
# 50%              1389.200000
# 75%              3778.525000
# max              8684.800000

# %%
df['Churn'].describe()
# Out:
# count     7043
# unique       2
# top         No
# freq      5174
# Name: Churn, dtype: object

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 5))
sns.countplot(x='Churn', data=df, palette='pastel', hue='Churn', legend=False)
plt.title('Distribución de Clientes por Churn')
plt.xlabel('Churn')
plt.ylabel('Número de Clientes')

total = len(df['Churn'])
for p in plt.gca().patches:
    height = p.get_height()
    plt.gca().text(p.get_x() + p.get_width()/2.,
                   height + 3,
                   '{:1.1f}%'.format(100*height/total),
                   ha='center', color='black', fontsize=12)

plt.show()

# %%
categorical_columns = df.select_dtypes(include='object').columns.tolist()
print("Columnas categóricas:")
print(categorical_columns)
# Out:
# Columnas categóricas:
# ['customerID', 'Churn', 'customer.gender', 'customer.Partner', 'customer.Dependents', 'phone.PhoneService', 'phone.MultipleLines', 'internet.InternetService', 'internet.OnlineSecurity', 'internet.OnlineBackup', 'internet.DeviceProtection', 'internet.TechSupport', 'internet.StreamingTV', 'internet.StreamingMovies', 'account.Contract', 'account.PaperlessBilling', 'account.PaymentMethod']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Agrupar el DataFrame df por 'customer.gender' y 'Churn', y contar el número de ocurrencias
gender_churn_counts = df.groupby(['customer.gender', 'Churn']).size().unstack(fill_value=0)

# 2. Calcular el porcentaje de churn ('Yes') y no churn ('No') dentro de cada género
gender_churn_porcentajes = gender_churn_counts.apply(lambda x: x / x.sum() * 100, axis=1)

# 3. Crear un gráfico de barras apiladas
plt.figure(figsize=(8, 6))
gender_churn_porcentajes.plot(kind='bar', stacked=True, colormap='Paired')

# 4. Añadir un título al gráfico
plt.title('Distribución de Churn por Género')

# 5. Añadir etiquetas a los ejes x e y
plt.xlabel('Género')
plt.ylabel('Porcentaje')
plt.xticks(rotation=0)

# Añadir las etiquetas de porcentaje dentro de las barras
for container in plt.gca().containers:
    for patch in container.patches:
        width = patch.get_width()
        height = patch.get_height()
        x, y = patch.get_xy()
        if height > 0:
            plt.text(x + width / 2, y + height / 2, f'{height:.1f}%', ha='center', va='center', color='black')

# 6. Mostrar el gráfico
plt.show()

# %% [markdown]
# *   **Churn entre Mujeres**: Aproximadamente el 26.9% de las clientas (`Female`) han abandonado la empresa, mientras que el 73.1% han permanecido.
# *   **Churn entre Hombres**: De manera similar, cerca del 26.2% de los clientes masculinos (`Male`) han abandonado la empresa, con un 73.8% que han permanecido.
#
# **Conclusión**: No se observa una diferencia significativa en la tasa de `Churn` entre hombres y mujeres. Ambos géneros muestran una proporción de abandono muy similar, lo que sugiere que el género por sí solo no es un factor determinante en la decisión de un cliente de dejar la empresa.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Agrupar el DataFrame df por 'account.Contract' y 'Churn', y contar el número de ocurrencias
contract_churn_counts = df.groupby(['account.Contract', 'Churn']).size().unstack(fill_value=0)

# 2. Calcular el porcentaje de churn ('Yes') y no churn ('No') dentro de cada tipo de contrato
contract_churn_porcentajes = contract_churn_counts.apply(lambda x: x / x.sum() * 100, axis=1)

# 3. Crear un gráfico de barras apiladas
plt.figure(figsize=(10, 7))
contract_churn_porcentajes.plot(kind='bar', stacked=True, colormap='viridis')

# 4. Añadir un título al gráfico
plt.title('Distribución de Churn por Tipo de Contrato')

# 5. Añadir etiquetas a los ejes x e y
plt.xlabel('Tipo de Contrato')
plt.ylabel('Porcentaje')
plt.xticks(rotation=0)

# 6. Añadir las etiquetas de porcentaje dentro de las barras
for container in plt.gca().containers:
    for patch in container.patches:
        width = patch.get_width()
        height = patch.get_height()
        x, y = patch.get_xy()
        if height > 0:
            plt.text(x + width / 2, y + height / 2, f'{height:.1f}%', ha='center', va='center', color='white', fontsize=10)

# 7. Mostrar el gráfico
plt.show()

# %% [markdown]
# *   **Contrato de Mes a Mes (Month-to-month)**: Este tipo de contrato muestra la tasa de churn más alta, con aproximadamente el 42.7% de los clientes abandonando la empresa, mientras que el 57.3% permanecen.
# *   **Contrato de Un Año (One year)**: La tasa de churn para los contratos de un año es significativamente menor, alrededor del 11.3%, con un 88.7% de retención.
# *   **Contrato de Dos Años (Two year)**: Los clientes con contratos de dos años tienen la tasa de churn más baja, con solo un 2.8% abandonando la empresa y un impresionante 97.2% de retención.
#
# **Conclusión**: Existe una fuerte correlación inversa entre la duración del contrato y la tasa de churn. Los clientes con contratos más largos (uno y dos años) son mucho más leales que aquellos con contratos de mes a mes. Esto sugiere que fomentar contratos a largo plazo podría ser una estrategia efectiva para reducir el churn.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Agrupar el DataFrame df por 'account.PaymentMethod' y 'Churn', y contar el número de ocurrencias
payment_method_churn_counts = df.groupby(['account.PaymentMethod', 'Churn']).size().unstack(fill_value=0)

# 2. Calcular el porcentaje de churn ('Yes') y no churn ('No') dentro de cada método de pago
payment_method_churn_porcentajes = payment_method_churn_counts.apply(lambda x: x / x.sum() * 100, axis=1)

# 3. Crear un gráfico de barras apiladas
plt.figure(figsize=(12, 7))
payment_method_churn_porcentajes.plot(kind='bar', stacked=True, colormap='Spectral')

# 4. Añadir un título al gráfico
plt.title('Distribución de Churn por Método de Pago')

# 5. Añadir etiquetas a los ejes x e y
plt.xlabel('Método de Pago')
plt.ylabel('Porcentaje')
plt.xticks(rotation=45, ha='right')

# 6. Añadir las etiquetas de porcentaje dentro de las barras
for container in plt.gca().containers:
    for patch in container.patches:
        width = patch.get_width()
        height = patch.get_height()
        x, y = patch.get_xy()
        if height > 0:
            plt.text(x + width / 2, y + height / 2, f'{height:.1f}%', ha='center', va='center', color='black', fontsize=9)

# 7. Mostrar el gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# *   **Cheque Electrónico (Electronic check)**: Este método de pago presenta la tasa de churn más alta, con aproximadamente el 45.3% de los clientes abandonando la empresa. Solo el 54.7% de los clientes que utilizan este método permanecen.
# *   **Cheque por Correo (Mailed check)**: La tasa de churn para este método es del 19.1%, lo que es significativamente menor que la de los cheques electrónicos, con un 80.9% de retención.
# *   **Transferencia Bancaria (Automática) (Bank transfer (automatic))**: Los clientes que pagan mediante transferencia bancaria automática tienen una tasa de churn del 16.7%, con un 83.3% de retención.
# *   **Tarjeta de Crédito (Automática) (Credit card (automatic))**: Este método de pago muestra la tasa de churn más baja, con un 15.2%, y la tasa de retención más alta, con un 84.8%.
#
# **Conclusión**: Existe una clara diferencia en las tasas de churn según el método de pago. Los clientes que utilizan el 'Cheque Electrónico' tienen casi el triple de probabilidades de churn que aquellos que usan 'Tarjeta de Crédito (automática)' o 'Transferencia Bancaria (automática)'. Esto sugiere que los métodos de pago automáticos están asociados con una mayor lealtad del cliente, y que el 'Cheque Electrónico' podría ser un indicador de insatisfacción o menor compromiso con el servicio.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Agrupar el DataFrame df por 'internet.InternetService' y 'Churn', y contar el número de ocurrencias
internet_service_churn_counts = df.groupby(['internet.InternetService', 'Churn']).size().unstack(fill_value=0)

# 2. Calcular el porcentaje de churn ('Yes') y no churn ('No') dentro de cada tipo de servicio de internet
internet_service_churn_porcentajes = internet_service_churn_counts.apply(lambda x: x / x.sum() * 100, axis=1)

# 3. Crear un gráfico de barras apiladas
plt.figure(figsize=(10, 7))
internet_service_churn_porcentajes.plot(kind='bar', stacked=True, colormap='Accent')

# 4. Añadir un título al gráfico
plt.title('Distribución de Churn por Servicio de Internet')

# 5. Añadir etiquetas a los ejes x e y
plt.xlabel('Servicio de Internet')
plt.ylabel('Porcentaje')
plt.xticks(rotation=0)

# 6. Añadir las etiquetas de porcentaje dentro de las barras
for container in plt.gca().containers:
    for patch in container.patches:
        width = patch.get_width()
        height = patch.get_height()
        x, y = patch.get_xy()
        if height > 0:
            plt.text(x + width / 2, y + height / 2, f'{height:.1f}%', ha='center', va='center', color='black', fontsize=10)

# 7. Mostrar el gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# *   **Fibra Óptica (Fiber optic)**: Este servicio presenta la tasa de churn más alta, con aproximadamente el 41.9% de los clientes abandonando la empresa, mientras que el 58.1% permanecen.
# *   **DSL**: La tasa de churn para los clientes con servicio DSL es significativamente menor, alrededor del 19.0%, con un 81.0% de retención.
# *   **Sin Servicio de Internet (No InternetService)**: Los clientes que no tienen servicio de internet tienen la tasa de churn más baja, con solo un 7.4% abandonando la empresa y un impresionante 92.6% de retención.
#
# **Conclusión**: Existe una clara correlación entre el tipo de servicio de internet y la tasa de churn. Los clientes con "Fibra Óptica" son los más propensos a churn, casi el doble que los de DSL, y seis veces más que los que no tienen servicio de internet. Esto podría indicar problemas de calidad, precio o expectativas no cumplidas con el servicio de fibra óptica, o que este segmento de clientes es más propenso a buscar alternativas.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Agrupar el DataFrame df por 'phone.PhoneService' y 'Churn', y contar el número de ocurrencias
phone_service_churn_counts = df.groupby(['phone.PhoneService', 'Churn']).size().unstack(fill_value=0)

# 2. Calcular el porcentaje de churn ('Yes') y no churn ('No') dentro de cada tipo de servicio telefónico
phone_service_churn_porcentajes = phone_service_churn_counts.apply(lambda x: x / x.sum() * 100, axis=1)

# 3. Crear un gráfico de barras apiladas
plt.figure(figsize=(8, 6))
phone_service_churn_porcentajes.plot(kind='bar', stacked=True, colormap='Pastel2')

# 4. Añadir un título al gráfico
plt.title('Distribución de Churn por Servicio Telefónico')

# 5. Añadir etiquetas a los ejes x e y
plt.xlabel('Servicio Telefónico')
plt.ylabel('Porcentaje')
plt.xticks(rotation=0)

# 6. Añadir las etiquetas de porcentaje dentro de las barras
for container in plt.gca().containers:
    for patch in container.patches:
        width = patch.get_width()
        height = patch.get_height()
        x, y = patch.get_xy()
        if height > 0:
            plt.text(x + width / 2, y + height / 2, f'{height:.1f}%', ha='center', va='center', color='black', fontsize=10)

# 7. Mostrar el gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# *   **Sin Servicio Telefónico (No PhoneService)**: Los clientes sin servicio telefónico tienen una tasa de churn del 24.9%, con un 75.1% de retención.
# *   **Con Servicio Telefónico (PhoneService Yes)**: Los clientes que sí tienen servicio telefónico muestran una tasa de churn ligeramente más alta, del 26.7%, con un 73.3% de retención.
#
# **Conclusión**: No se observa una diferencia significativa en la tasa de `Churn` entre los clientes que tienen servicio telefónico y los que no. La tasa de abandono es muy similar en ambos grupos, lo que sugiere que la presencia o ausencia de un servicio telefónico básico por sí sola no es un factor determinante en la decisión de un cliente de dejar la empresa.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Crear una figura con dos subplots
plt.figure(figsize=(16, 6))

# Subplot 1: Boxplot de 'customer.tenure' agrupado por 'Churn'
plt.subplot(1, 2, 1)
sns.boxplot(x='Churn', y='customer.tenure', data=df, palette='viridis')
plt.title('Boxplot de Tenure por Churn')
plt.xlabel('Churn')
plt.ylabel('Meses de Contrato (Tenure)')

# Subplot 2: KDE Plot de 'customer.tenure' agrupado por 'Churn'
plt.subplot(1, 2, 2)
sns.kdeplot(data=df, x='customer.tenure', hue='Churn', fill=True, palette='viridis', common_norm=False)
plt.title('KDE Plot de Tenure por Churn')
plt.xlabel('Meses de Contrato (Tenure)')
plt.ylabel('Densidad')

# Ajustar el layout y mostrar los gráficos
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-301/3329667927.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Churn', y='customer.tenure', data=df, palette='viridis')

# %% [markdown]
# A continuación, se presenta un resumen de los patrones y tendencias observados en la distribución de la columna `customer.tenure` (meses de contrato) para clientes con y sin `Churn`:
#
# **Análisis de 'customer.tenure' y Churn:**
#
# *   **Clientes que no han abandonado (No Churn):** Los boxplots y KDE plots muestran que los clientes que no han abandonado la empresa (`No`) tienden a tener una `tenure` (antigüedad) significativamente más alta. La distribución para estos clientes se inclina hacia valores de `tenure` más largos, con una mediana notablemente superior y un rango intercuartílico que se extiende a más meses de contrato. El KDE plot de 'No Churn' presenta un pico más pronunciado en valores de `tenure` más altos, indicando una mayor concentración de clientes leales con mayor antigüedad.
#
# *   **Clientes que han abandonado (Churn):** Por otro lado, los clientes que han abandonado la empresa (`Yes`) muestran una `tenure` considerablemente más baja. La distribución para este grupo está sesgada hacia `tenure` más cortas, con una mediana muy inferior a la de los clientes 'No Churn'. El KDE plot para 'Churn' tiene un pico prominente en los primeros meses de contrato, lo que sugiere que muchos clientes que abandonan lo hacen poco después de contratar el servicio.
#
# **Patrones y Tendencias Clave:**
#
# 1.  **Antigüedad como predictor de Churn:** Existe una fuerte relación inversa entre la `tenure` y la probabilidad de churn. Los clientes con menos tiempo en la empresa son mucho más propensos a abandonarla.
# 2.  **Etapa temprana crítica:** La alta densidad de churn en los primeros meses de contrato resalta la importancia de la experiencia del cliente durante la fase inicial del servicio. Mejorar la integración y satisfacción en este período podría reducir la tasa de abandono.
# 3.  **Lealtad a largo plazo:** Los clientes que superan los primeros meses y permanecen más tiempo tienden a ser más estables y menos propensos a churnear, lo que indica que una vez que se establecen, la lealtad del cliente aumenta.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Crear una figura con dos subplots
plt.figure(figsize=(16, 6))

# Subplot 1: Boxplot de 'account.Charges.Monthly' agrupado por 'Churn'
plt.subplot(1, 2, 1)
sns.boxplot(x='Churn', y='account.Charges.Monthly', data=df, hue='Churn', palette='mako', legend=False)
plt.title('Boxplot de Cargos Mensuales por Churn')
plt.xlabel('Churn')
plt.ylabel('Cargos Mensuales (account.Charges.Monthly)')

# Subplot 2: KDE Plot de 'account.Charges.Monthly' agrupado por 'Churn'
plt.subplot(1, 2, 2)
sns.kdeplot(data=df, x='account.Charges.Monthly', hue='Churn', fill=True, palette='mako', common_norm=False)
plt.title('KDE Plot de Cargos Mensuales por Churn')
plt.xlabel('Cargos Mensuales (account.Charges.Monthly)')
plt.ylabel('Densidad')

# Ajustar el layout y mostrar los gráficos
plt.tight_layout()
plt.show()

# %% [markdown]
# A continuación, se presenta un resumen de los patrones y tendencias observados en la distribución de la columna `account.Charges.Monthly` (total de todos los servicios del cliente por mes) para clientes con y sin `Churn`:
#
# **Análisis de 'account.Charges.Monthly' y Churn:**
#
# *   **Clientes que no han abandonado (No Churn):** Los boxplots y KDE plots para los clientes que no han abandonado la empresa (`No`) muestran una distribución de cargos mensuales más amplia, con una concentración en cargos más bajos y medios. La mediana para este grupo es generalmente más baja que la de los clientes que han churn. El KDE plot para 'No Churn' tiende a tener un pico más bajo y una cola más larga hacia cargos más bajos, lo que sugiere que muchos clientes con cargos mensuales moderados son más estables.
#
# *   **Clientes que han abandonado (Churn):** Por otro lado, los clientes que han abandonado la empresa (`Yes`) muestran una tendencia a tener cargos mensuales más altos. La distribución para este grupo se desplaza hacia la derecha en los gráficos, con una mediana y un cuartil superior notablemente más altos que los de los clientes 'No Churn'. El KDE plot para 'Churn' presenta un pico más prominente en valores de cargos mensuales más altos, lo que indica que los clientes que pagan más mensualmente son más propensos a abandonar.
#
# **Patrones y Tendencias Clave:**
#
# 1.  **Cargos Mensuales Altos y Churn:** Existe una correlación positiva entre cargos mensuales elevados y la probabilidad de churn. Los clientes con facturas mensuales más altas son más propensos a abandonar.
# 2.  **Sensibilidad al Precio:** Esto podría indicar que los clientes con servicios más costosos son más sensibles al precio o que no perciben un valor adecuado por el costo de sus servicios, llevándolos a buscar alternativas.
# 3.  **Diferencia de Distribución:** La clara separación en las medianas y distribuciones entre los grupos 'Yes' y 'No' para `account.Charges.Monthly` sugiere que este es un predictor importante del churn. Los clientes con cargos mensuales bajos y medios son más propensos a retenerse, mientras que aquellos con cargos más altos son un grupo de riesgo.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Crear una figura con dos subplots
plt.figure(figsize=(16, 6))

# Subplot 1: Boxplot de 'account.Charges.Total' agrupado por 'Churn'
plt.subplot(1, 2, 1)
sns.boxplot(x='Churn', y='account.Charges.Total', data=df, hue='Churn', palette='plasma', legend=False)
plt.title('Boxplot de Cargos Totales por Churn')
plt.xlabel('Churn')
plt.ylabel('Cargos Totales (account.Charges.Total)')

# Subplot 2: KDE Plot de 'account.Charges.Total' agrupado por 'Churn'
plt.subplot(1, 2, 2)
sns.kdeplot(data=df, x='account.Charges.Total', hue='Churn', fill=True, palette='plasma', common_norm=False)
plt.title('KDE Plot de Cargos Totales por Churn')
plt.xlabel('Cargos Totales (account.Charges.Total)')
plt.ylabel('Densidad')

# Ajustar el layout y mostrar los gráficos
plt.tight_layout()
plt.show()

# %% [markdown]
# A continuación, se presenta un resumen de los patrones y tendencias observados en la distribución de la columna `account.Charges.Total` (total gastado por el cliente) para clientes con y sin `Churn`:
#
# **Análisis de 'account.Charges.Total' y Churn:**
#
# *   **Clientes que no han abandonado (No Churn):** Los boxplots y KDE plots para los clientes que no han abandonado la empresa (`No`) muestran una distribución con un rango más amplio de `Charges.Total`, indicando que estos clientes, en promedio, han gastado más en total a lo largo de su relación con la empresa. La distribución tiende a tener valores más altos, reflejando su mayor antigüedad (`tenure`). La mediana es significativamente más alta, y el KDE plot muestra una concentración en valores de cargos totales más elevados.
#
# *   **Clientes que han abandonado (Churn):** Por otro lado, los clientes que han abandonado la empresa (`Yes`) muestran una distribución de `Charges.Total` que está fuertemente sesgada hacia valores más bajos. Esto es consistente con la observación de que los clientes que churn tienden a tener una `tenure` más corta. La mediana de los cargos totales para este grupo es considerablemente más baja. El KDE plot para 'Churn' presenta un pico prominente en los valores de cargos totales más bajos, lo que subraya que el abandono ocurre más a menudo entre clientes con un gasto total reducido.
#
# **Patrones y Tendencias Clave:**
#
# 1.  **Gasto Total como Indicador de Lealtad:** Existe una clara correlación positiva entre el `account.Charges.Total` y la retención del cliente. Los clientes que han permanecido más tiempo y, por lo tanto, han acumulado un mayor gasto total, son menos propensos a abandonar.
# 2.  **Churn en Clientes de Bajo Gasto Total:** La alta concentración de churn entre clientes con bajos cargos totales refuerza la idea de que los clientes nuevos o aquellos que no han invertido mucho en los servicios de la empresa son un segmento de alto riesgo.
# 3.  **Relación con la Antigüedad:** Las distribuciones de `account.Charges.Total` son coherentes con las de `customer.tenure`. Un `tenure` más largo naturalmente lleva a un `Charges.Total` más alto (asumiendo que los cargos mensuales son constantes o aumentan), lo que refuerza la idea de que la longevidad del cliente es crucial para la retención.

# %% [markdown]
# ## Resumen:
#
# ### Hallazgos Clave del Análisis de Datos
#
# * **Antigüedad del Cliente:**
# * Los clientes que **no abandonaron** (`No`) tienden a tener una duración de contrato significativamente mayor (antigüedad)**, lo que indica mayor lealtad y estabilidad.
# * Los clientes que **sí abandonaron** (`Sí`) muestran una fuerte tendencia a tener una duración más corta, y muchos abandonan el servicio en los primeros meses de su contrato. Esto pone de relieve la importancia del período inicial de servicio.
# * **Cargos Mensuales:**
# * Los clientes que **no abandonaron** (`No`) presentan una distribución más amplia de cargos mensuales, concentrándose en valores **bajos a medios**.
# * Los clientes que **sí abandonaron** (`Sí`) tienden a tener cargos mensuales más altos, lo que sugiere una correlación positiva entre los costos mensuales elevados y la probabilidad de abandono. Esto podría indicar una mayor sensibilidad al precio entre los clientes con servicios más caros. * **Cargos Totales:**
# * Los clientes que **no abandonaron** (`No`) generalmente presentan **cargos totales más altos**, lo que coincide con su mayor antigüedad y compromiso continuo.
# * Los clientes que **sí abandonaron** (`Sí`) muestran una distribución con una marcada tendencia hacia **cargos totales más bajos**, lo que se alinea con la menor duración de sus contratos y su menor gasto total. Esto indica que la pérdida de clientes es más frecuente entre los clientes con un gasto acumulado mínimo.
#
# ### Perspectivas o Próximos Pasos
#
# * **Enfoque en la Experiencia Temprana del Cliente:** Dado que una parte significativa de la pérdida de clientes ocurre durante los primeros meses del contrato y entre clientes con cargos totales bajos, se deben concentrar los esfuerzos en mejorar el proceso de incorporación y garantizar la satisfacción temprana para prolongar la permanencia del cliente.
# * **Reevaluar el Valor del Servicio de Alto Nivel:** La mayor tasa de pérdida de clientes entre los clientes con cargos mensuales elevados sugiere un posible problema con la relación calidad-precio percibida en los niveles de servicio más caros. Analizar los comentarios de los clientes y las ofertas de servicios para estos segmentos podría ayudar en las estrategias de retención.

# %% [markdown]
# #**📄Informe final**

# %% [markdown]
# # Informe de Análisis de Churn para Telecom X
#
# ## Introducción
#
# El presente informe tiene como objetivo principal analizar en profundidad el fenómeno de la rotación de clientes, o 'Churn', en la empresa de telecomunicaciones Telecom X. A través de este análisis, buscamos identificar los factores clave que influyen en la decisión de los clientes de abandonar la empresa, así como comprender los patrones y tendencias asociados a este comportamiento. La meta es proporcionar información valiosa que permita a Telecom X desarrollar estrategias de retención más efectivas y personalizadas.
#
# El Churn de clientes representa un desafío crítico para las empresas en la industria de las telecomunicaciones. Cada cliente que abandona no solo significa una pérdida directa de ingresos recurrentes, sino que también implica un impacto negativo en el crecimiento general de la empresa y en el valor de vida útil del cliente (CLTV). Además, adquirir nuevos clientes es significativamente más costoso que retener a los existentes. Por lo tanto, comprender y mitigar el Churn es fundamental para la sostenibilidad y el éxito a largo plazo de Telecom X.

# %% [markdown]
# ## Limpieza y Tratamiento de Datos
#
# 1.  **Importación del Dataset**: Inicialmente, los datos se importaron desde el archivo `TelecomX_Data.json` utilizando la función `pd.read_json()` de la librería pandas. Esto cargó los datos en el DataFrame `df_local`.
#
# 2.  **Aplanamiento de Columnas Anidadas**: El DataFrame original contenía columnas con estructuras anidadas (`customer`, `phone`, `internet`, `account`). Para aplanar estas columnas y hacer los datos más accesibles, se aplicó el siguiente proceso:
#     *   Cada una de estas columnas anidadas, que eran diccionarios, fue convertida en una serie de nuevas columnas. Por ejemplo, la columna `customer` se expandió en `customer.gender`, `customer.SeniorCitizen`, `customer.Partner`, `customer.Dependents`, y `customer.tenure`.
#     *   Para lograr esto, se iteró sobre las columnas anidadas y se utilizó la función `json_normalize` para extraer sus claves como nombres de columnas y sus valores como los datos correspondientes, prefijando los nombres de las nuevas columnas para mantener la identificación de su origen.
#
# 3.  **Tratamiento de Valores Nulos en `account.Charges.Total`**:
#     *   Se identificó que la columna `account.Charges.Total` era de tipo `object` y contenía valores que impedían su conversión directa a un tipo numérico (por ejemplo, cadenas vacías).
#     *   Para resolver esto, se utilizó `pd.to_numeric(df['account.Charges.Total'], errors='coerce')`. El argumento `errors='coerce'` convirtió cualquier valor no numérico (como las cadenas vacías) en `NaN` (Not a Number).
#     *   Posteriormente, los valores `NaN` generados fueron reemplazados por `0` utilizando `df['account.Charges.Total'].fillna(0)`, asegurando que la columna fuera completamente numérica y sin valores faltantes para el análisis de totales.
#
# 4.  **Tratamiento de Valores Nulos en `Churn`**:
#     *   Se detectaron valores nulos (`NaN`) en la columna `Churn`, la cual es la variable objetivo del análisis.
#     *   Para garantizar la integridad del análisis de Churn, se eliminaron las filas donde la columna `Churn` presentaba valores `NaN` utilizando `df.dropna(subset=['Churn'])`. Esto aseguró que solo se trabajara con registros completos y definidos para la variable de abandono.

# %% [markdown]
# ## Análisis Exploratorio de Datos (EDA)
#
# ### Distribución General de Churn
# *   **Distribución de Clientes por Churn:** Del total de clientes, el 26.9% ha abandonado la empresa (`Yes`), mientras que el 73.1% ha permanecido (`No`). Esta proporción inicial ya indica que la tasa de churn es un factor relevante para la empresa, con aproximadamente un cuarto de los clientes yéndose.
#
# ### Análisis de Variables Categóricas y Churn
#
# *   **Churn por Género (`customer.gender`):**
#     *   **Churn entre Mujeres**: Aproximadamente el 26.9% de las clientas (`Female`) han abandonado la empresa, mientras que el 73.1% han permanecido.
#     *   **Churn entre Hombres**: De manera similar, cerca del 26.2% de los clientes masculinos (`Male`) han abandonado la empresa, con un 73.8% que han permanecido.
#     *   **Conclusión**: No se observa una diferencia significativa en la tasa de `Churn` entre hombres y mujeres. Ambos géneros muestran una proporción de abandono muy similar, lo que sugiere que el género por sí solo no es un factor determinante en la decisión de un cliente de dejar la empresa.
#
# *   **Churn por Tipo de Contrato (`account.Contract`):**
#     *   **Contrato de Mes a Mes (Month-to-month)**: Este tipo de contrato muestra la tasa de churn más alta, con aproximadamente el 42.7% de los clientes abandonando la empresa, mientras que el 57.3% permanecen.
#     *   **Contrato de Un Año (One year)**: La tasa de churn para los contratos de un año es significativamente menor, alrededor del 11.3%, con un 88.7% de retención.
#     *   **Contrato de Dos Años (Two year)**: Los clientes con contratos de dos años tienen la tasa de churn más baja, con solo un 2.8% abandonando la empresa y un impresionante 97.2% de retención.
#     *   **Conclusión**: Existe una fuerte correlación inversa entre la duración del contrato y la tasa de churn. Los clientes con contratos más largos (uno y dos años) son mucho más leales que aquellos con contratos de mes a mes. Esto sugiere que fomentar contratos a largo plazo podría ser una estrategia efectiva para reducir el churn.
#
# *   **Churn por Método de Pago (`account.PaymentMethod`):**
#     *   **Cheque Electrónico (Electronic check)**: Este método de pago presenta la tasa de churn más alta, con aproximadamente el 45.3% de los clientes abandonando la empresa. Solo el 54.7% de los clientes que utilizan este método permanecen.
#     *   **Cheque por Correo (Mailed check)**: La tasa de churn para este método es del 19.1%, lo que es significativamente menor que la de los cheques electrónicos, con un 80.9% de retención.
#     *   **Transferencia Bancaria (Automática) (Bank transfer (automatic))**: Los clientes que pagan mediante transferencia bancaria automática tienen una tasa de churn del 16.7%, con un 83.3% de retención.
#     *   **Tarjeta de Crédito (Automática) (Credit card (automatic))**: Este método de pago muestra la tasa de churn más baja, con un 15.2%, y la tasa de retención más alta, con un 84.8%.
#     *   **Conclusión**: Existe una clara diferencia en las tasas de churn según el método de pago. Los clientes que utilizan el 'Cheque Electrónico' tienen casi el triple de probabilidades de churn que aquellos que usan 'Tarjeta de Crédito (automática)' o 'Transferencia Bancaria (automática)'. Esto sugiere que los métodos de pago automáticos están asociados con una mayor lealtad del cliente, y que el 'Cheque Electrónico' podría ser un indicador de insatisfacción o menor compromiso con el servicio.
#
# *   **Churn por Servicio de Internet (`internet.InternetService`):**
#     *   **Fibra Óptica (Fiber optic)**: Este servicio presenta la tasa de churn más alta, con aproximadamente el 41.9% de los clientes abandonando la empresa, mientras que el 58.1% permanecen.
#     *   **DSL**: La tasa de churn para los clientes con servicio DSL es significativamente menor, alrededor del 19.0%, con un 81.0% de retención.
#     *   **Sin Servicio de Internet (No InternetService)**: Los clientes que no tienen servicio de internet tienen la tasa de churn más baja, con solo un 7.4% abandonando la empresa y un impresionante 92.6% de retención.
#     *   **Conclusión**: Existe una clara correlación entre el tipo de servicio de internet y la tasa de churn. Los clientes con "Fibra Óptica" son los más propensos a churn, casi el doble que los de DSL, y seis veces más que los que no tienen servicio de internet. Esto podría indicar problemas de calidad, precio o expectativas no cumplidas con el servicio de fibra óptica, o que este segmento de clientes es más propenso a buscar alternativas.
#
# *   **Churn por Servicio Telefónico (`phone.PhoneService`):**
#     *   **Sin Servicio Telefónico (No PhoneService)**: Los clientes sin servicio telefónico tienen una tasa de churn del 24.9%, con un 75.1% de retención.
#     *   **Con Servicio Telefónico (PhoneService Yes)**: Los clientes que sí tienen servicio telefónico muestran una tasa de churn ligeramente más alta, del 26.7%, con un 73.3% de retención.
#     *   **Conclusión**: No se observa una diferencia significativa en la tasa de `Churn` entre los clientes que tienen servicio telefónico y los que no. La tasa de abandono es muy similar en ambos grupos, lo que sugiere que la presencia o ausencia de un servicio telefónico básico por sí sola no es un factor determinante en la decisión de un cliente de dejar la empresa.
#
# ### Análisis de Variables Numéricas y Churn
#
# *   **Churn por Meses de Contrato (`customer.tenure`):**
#     *   **Clientes que no han abandonado (No Churn):** Los boxplots y KDE plots muestran que los clientes que no han abandonado la empresa (`No`) tienden a tener una `tenure` (antigüedad) significativamente más alta. La distribución para estos clientes se inclina hacia valores de `tenure` más largos, con una mediana notablemente superior y un rango intercuartílico que se extiende a más meses de contrato. El KDE plot de 'No Churn' presenta un pico más pronunciado en valores de `tenure` más altos, indicando una mayor concentración de clientes leales con mayor antigüedad.
#     *   **Clientes que han abandonado (Churn):** Por otro lado, los clientes que han abandonado la empresa (`Yes`) muestran una `tenure` considerablemente más baja. La distribución para este grupo está sesgada hacia `tenure` más cortas, con una mediana muy inferior a la de los clientes 'No Churn'. El KDE plot para 'Churn' tiene un pico prominente en los primeros meses de contrato, lo que sugiere que muchos clientes que abandonan lo hacen poco después de contratar el servicio.
#     *   **Conclusión**: Existe una fuerte relación inversa entre la `tenure` y la probabilidad de churn. Los clientes con menos tiempo en la empresa son mucho más propensos a abandonarla. La alta densidad de churn en los primeros meses de contrato resalta la importancia de la experiencia del cliente durante la fase inicial del servicio.
#
# *   **Churn por Cargos Mensuales (`account.Charges.Monthly`):**
#     *   **Clientes que no han abandonado (No Churn):** Los boxplots y KDE plots para los clientes que no han abandonado la empresa (`No`) muestran una distribución de cargos mensuales más amplia, con una concentración en cargos más bajos y medios. La mediana para este grupo es generalmente más baja que la de los clientes que han churn. El KDE plot para 'No Churn' tiende a tener un pico más bajo y una cola más larga hacia cargos más bajos, lo que sugiere que muchos clientes con cargos mensuales moderados son más estables.
#     *   **Clientes que han abandonado (Churn):** Por otro lado, los clientes que han abandonado la empresa (`Yes`) muestran una tendencia a tener cargos mensuales más altos. La distribución para este grupo se desplaza hacia la derecha en los gráficos, con una mediana y un cuartil superior notablemente más altos que los de los clientes 'No Churn'. El KDE plot para 'Churn' presenta un pico más prominente en valores de cargos mensuales más altos, lo que indica que los clientes que pagan más mensualmente son más propensos a abandonar.
#     *   **Conclusión**: Existe una correlación positiva entre cargos mensuales elevados y la probabilidad de churn. Los clientes con facturas mensuales más altas son más propensos a abandonar, lo que podría indicar sensibilidad al precio o una percepción de valor inadecuada para el costo de sus servicios.
#
# *   **Churn por Cargos Totales (`account.Charges.Total`):**
#     *   **Clientes que no han abandonado (No Churn):** Los boxplots y KDE plots para los clientes que no han abandonado la empresa (`No`) muestran una distribución con un rango más amplio de `Charges.Total`, indicando que estos clientes, en promedio, han gastado más en total a lo largo de su relación con la empresa. La mediana es significativamente más alta, y el KDE plot muestra una concentración en valores de cargos totales más elevados.
#     *   **Clientes que han abandonado (Churn):** Por otro lado, los clientes que han abandonado la empresa (`Yes`) muestran una distribución de `Charges.Total` que está fuertemente sesgada hacia valores más bajos. Esto es consistente con la observación de que los clientes que churn tienden a tener una `tenure` más corta. La mediana de los cargos totales para este grupo es considerablemente más baja. El KDE plot para 'Churn' presenta un pico prominente en los valores de cargos totales más bajos, lo que subraya que el abandono ocurre más a menudo entre clientes con un gasto total reducido.
#     *   **Conclusión**: Existe una clara correlación positiva entre el `account.Charges.Total` y la retención del cliente. Los clientes que han permanecido más tiempo y, por lo tanto, han acumulado un mayor gasto total, son menos propensos a abandonar. La alta concentración de churn entre clientes con bajos cargos totales refuerza la idea de que los clientes nuevos o aquellos que no han invertido mucho en los servicios de la empresa son un segmento de alto riesgo.

# %% [markdown]
# ## Conclusiones e Insights
#
# El análisis exploratorio de datos (EDA) ha revelado varios factores clave que influyen significativamente en la tasa de abandono de clientes (churn) de Telecom X. A continuación, se resumen los hallazgos más impactantes y las implicaciones para la reducción del churn:
#
# ### Hallazgos Clave:
#
# 1.  **Antigüedad del Cliente (Tenure):** Existe una fuerte relación inversa entre la antigüedad del cliente y el churn. Los clientes con menor tiempo en la empresa (especialmente en los primeros meses) son significativamente más propensos a abandonar. Esto sugiere que el período inicial de la relación con el cliente es crítico.
#
# 2.  **Tipo de Contrato:** Los clientes con contratos mes a mes (`Month-to-month`) tienen la tasa de churn más alta (aproximadamente 42.7%), mientras que aquellos con contratos de uno y dos años muestran tasas de churn drásticamente más bajas (11.3% y 2.8% respectivamente). Los contratos a largo plazo fomentan una mayor lealtad.
#
# 3.  **Método de Pago:** El método de pago 'Cheque Electrónico' (`Electronic check`) está asociado con la tasa de churn más alta (aproximadamente 45.3%). Los métodos de pago automáticos (tarjeta de crédito y transferencia bancaria) presentan tasas de churn mucho menores, lo que podría indicar mayor satisfacción y compromiso.
#
# 4.  **Servicio de Internet:** Los clientes con servicio de 'Fibra Óptica' (`Fiber optic`) tienen la tasa de churn más elevada (aproximadamente 41.9%), mientras que los de 'DSL' y los que no tienen servicio de internet tienen tasas de churn considerablemente más bajas. Esto podría apuntar a problemas específicos con la calidad o el valor percibido del servicio de fibra óptica.
#
# 5.  **Cargos Mensuales y Totales:** Los clientes que abandonan tienden a tener cargos mensuales más altos, lo que sugiere una mayor sensibilidad al precio o una percepción de menor valor por el costo de sus servicios. Por otro lado, los clientes que no abandonan tienen cargos totales más altos, lo cual es coherente con su mayor antigüedad y mayor gasto acumulado.
#
# ### Cómo reducir la tasa de evasión de clientes para Telecom X:
#
# *   **Fortalecer la Retención en la Etapa Temprana:** Telecom X debe implementar programas de incorporación y seguimiento proactivos durante los primeros meses del contrato. Esto podría incluir llamadas de bienvenida personalizadas, soporte técnico prioritario, ofertas exclusivas para nuevos clientes o revisiones de servicio para asegurar la satisfacción y resolver cualquier problema inicial.
#
# *   **Fomentar Contratos a Largo Plazo:** Se recomienda incentivar a los clientes de 'mes a mes' a cambiar a contratos de uno o dos años mediante descuentos, mejoras de servicio, o paquetes promocionales. Comunicar claramente los beneficios de los contratos a largo plazo, como precios más estables y servicios adicionales, podría ser efectivo.
#
# *   **Optimizar Métodos de Pago:** Promover activamente la adopción de métodos de pago automáticos (tarjeta de crédito, transferencia bancaria) sobre el 'Cheque Electrónico' podría ayudar a reducir el churn. Esto podría hacerse a través de incentivos por cambiar el método de pago o educando a los clientes sobre la conveniencia y seguridad de las opciones automáticas.
#
# *   **Revisar el Servicio de Fibra Óptica:** Es crucial investigar las razones detrás del alto churn entre los usuarios de 'Fibra Óptica'. Esto podría implicar una evaluación de la calidad del servicio, la velocidad real vs. prometida, la competitividad de precios frente a la competencia, o la mejora del soporte técnico para este segmento. Abordar las causas subyacentes puede mejorar significativamente la retención.
#
# *   **Estrategias de Precios y Valor:** Para los clientes con cargos mensuales altos, Telecom X podría ofrecer revisiones personalizadas de su plan para asegurar que estén obteniendo el mejor valor, o introducir programas de fidelización que recompensen el gasto elevado con beneficios adicionales. Esto puede contrarrestar la percepción de que están pagando demasiado por el servicio.
#
# Al abordar estas áreas, Telecom X puede desarrollar estrategias de retención más dirigidas y efectivas, transformando los datos en acciones concretas para mejorar la lealtad del cliente y reducir el churn.
